# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
city_weather = requests.get(url + "&q=Boston").json()
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 38.32,
#   'feels_like': 35.37,
#   'temp_min': 34.95,
#   'temp_max': 41.58,
#   'pressure': 1014,
#   'humidity': 50},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 287, 'gust': 15.01},
#  'clouds': {'all': 75},
#  'dt': 1638292451,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1638273190,
#   'sunset': 1638306795},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
city_weather["weather"][0]["description"]
# Out:
# 'broken clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | havelock
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | nyrob
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | nacozari
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | conakry
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | bossangoa
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | jishou
# Processing Record 20 of Set 1 | lyaskelya
# Processing Record 21 of Set 1 | graaff-reinet
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | inuvik
# Processing Record 26 of Set 1 | salta
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | muros
# Processing Record 29 of Set 1 | port-cartier
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | calca
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | san cristobal
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | richards bay
# Processing Record 41 of Set 1 | gelendzhik
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | yerbogachen
# Processing Record 45 of Set 1 | poum
# Processing Record 46 of Set 1 | dipkarpaz
# City not found. Skipping...
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | sorland
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | zavodoukovsk
# Processing Record 1 of Set 2 | lata
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | the valley
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | provost
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | laguna
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | lazaro cardenas
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | luoyang
# Processing Record 22 of Set 2 | mikhaylovka
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | burica
# City not found. Skipping...
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | dhidhdhoo
# Processing Record 31 of Set 2 | lahaina
# Processing Record 32 of Set 2 | bela
# Processing Record 33 of Set 2 | malaya vishera
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | tres arroyos
# Processing Record 36 of Set 2 | baykit
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | nalut
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | waingapu
# Processing Record 41 of Set 2 | najran
# Processing Record 42 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 49 of Set 2 | sisimiut
# Processing Record 50 of Set 2 | loreto
# Processing Record 1 of Set 3 | brainerd
# Processing Record 2 of Set 3 | batagay
# Processing Record 3 of Set 3 | mareeba
# Processing Record 4 of Set 3 | avera
# Processing Record 5 of Set 3 | osakarovka
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | vostok
# Processing Record 8 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 3 | pitimbu
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | alice springs
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | bandarbeyla
# Processing Record 17 of Set 3 | kismayo
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | haines junction
# Processing Record 21 of Set 3 | andenes
# Processing Record 22 of Set 3 | rayong
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | genhe
# Processing Record 26 of Set 3 | calvia
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | flinders
# Processing Record 30 of Set 3 | misratah
# Processing Record 31 of Set 3 | bitung
# Processing Record 32 of Set 3 | formosa do rio preto
# Processing Record 33 of Set 3 | puyo
# Processing Record 34 of Set 3 | ola
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | bay roberts
# Processing Record 37 of Set 3 | port hedland
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | lethem
# Processing Record 40 of Set 3 | larap
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | saint-joseph
# Processing Record 45 of Set 3 | aquiraz
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | beringovskiy
# Processing Record 49 of Set 3 | auki
# Processing Record 50 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | kapaa
# Processing Record 4 of Set 4 | anloga
# Processing Record 5 of Set 4 | vestmannaeyjar
# Processing Record 6 of Set 4 | atka
# City not found. Skipping...
# Processing Record 7 of Set 4 | itaituba
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | mackay
# Processing Record 10 of Set 4 | abonnema
# Processing Record 11 of Set 4 | hopfgarten
# Processing Record 12 of Set 4 | tubarao
# Processing Record 13 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | santarem
# Processing Record 17 of Set 4 | boddam
# Processing Record 18 of Set 4 | bonnyville
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | puerto escondido
# Processing Record 21 of Set 4 | harper
# Processing Record 22 of Set 4 | minab
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | boysun
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | garissa
# Processing Record 27 of Set 4 | biltine
# Processing Record 28 of Set 4 | rupert
# Processing Record 29 of Set 4 | putina
# Processing Record 30 of Set 4 | mopti
# Processing Record 31 of Set 4 | nabire
# Processing Record 32 of Set 4 | virginia beach
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | marsa matruh
# Processing Record 35 of Set 4 | tuy hoa
# Processing Record 36 of Set 4 | mutis
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | cayenne
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | centralia
# Processing Record 43 of Set 4 | half moon bay
# Processing Record 44 of Set 4 | araouane
# Processing Record 45 of Set 4 | koslan
# Processing Record 46 of Set 4 | saurimo
# Processing Record 47 of Set 4 | rancho palos verdes
# Processing Record 48 of Set 4 | bajil
# Processing Record 49 of Set 4 | aykhal
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | imbituba
# Processing Record 2 of Set 5 | rocha
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | krasnoarmeysk
# Processing Record 5 of Set 5 | kiunga
# Processing Record 6 of Set 5 | tourlaville
# Processing Record 7 of Set 5 | hovd
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | sakata
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | thinadhoo
# Processing Record 12 of Set 5 | aiken
# Processing Record 13 of Set 5 | ossora
# Processing Record 14 of Set 5 | beloha
# Processing Record 15 of Set 5 | north bend
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | muzhi
# Processing Record 18 of Set 5 | hargeysa
# Processing Record 19 of Set 5 | adrar
# Processing Record 20 of Set 5 | witu
# Processing Record 21 of Set 5 | pacific grove
# Processing Record 22 of Set 5 | prince rupert
# Processing Record 23 of Set 5 | fairbanks
# Processing Record 24 of Set 5 | takestan
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | nuuk
# Processing Record 27 of Set 5 | lakhimpur
# Processing Record 28 of Set 5 | aqtobe
# Processing Record 29 of Set 5 | nome
# Processing Record 30 of Set 5 | dubti
# Processing Record 31 of Set 5 | tazovskiy
# Processing Record 32 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 5 | castro
# Processing Record 34 of Set 5 | alihe
# Processing Record 35 of Set 5 | emerald
# Processing Record 36 of Set 5 | tahe
# Processing Record 37 of Set 5 | mehamn
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | shakiso
# Processing Record 40 of Set 5 | uvira
# Processing Record 41 of Set 5 | sanand
# Processing Record 42 of Set 5 | hofn
# Processing Record 43 of Set 5 | zhezkazgan
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | okha
# Processing Record 47 of Set 5 | pahalgam
# Processing Record 48 of Set 5 | amberieu-en-bugey
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | puertollano
# Processing Record 1 of Set 6 | umm lajj
# Processing Record 2 of Set 6 | butaritari
# Processing Record 3 of Set 6 | meadow lake
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | gudari
# Processing Record 6 of Set 6 | marawi
# Processing Record 7 of Set 6 | rakiv lis
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | nizhneivkino
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | kotelnikovo
# Processing Record 12 of Set 6 | ternate
# Processing Record 13 of Set 6 | torbat-e jam
# Processing Record 14 of Set 6 | riohacha
# Processing Record 15 of Set 6 | tateyama
# Processing Record 16 of Set 6 | energeticheskiy
# Processing Record 17 of Set 6 | kerouane
# Processing Record 18 of Set 6 | mayo
# Processing Record 19 of Set 6 | tecoanapa
# Processing Record 20 of Set 6 | hami
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | san patricio
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | los llanos de aridane
# Processing Record 27 of Set 6 | tiksi
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | bathsheba
# Processing Record 30 of Set 6 | ugoofaaru
# Processing Record 31 of Set 6 | tay ninh
# Processing Record 32 of Set 6 | aden
# Processing Record 33 of Set 6 | labuhan
# Processing Record 34 of Set 6 | torbay
# Processing Record 35 of Set 6 | santiago
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | mpongwe
# Processing Record 38 of Set 6 | raymondville
# Processing Record 39 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 6 | cuiluan
# Processing Record 41 of Set 6 | yarada
# Processing Record 42 of Set 6 | tessalit
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | bubaque
# Processing Record 45 of Set 6 | superior
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | norman wells
# Processing Record 48 of Set 6 | nouadhibou
# Processing Record 49 of Set 6 | wampusirpi
# City not found. Skipping...
# Processing Record 50 of Set 6 | kruisfontein
# Processing Record 1 of Set 7 | salinas
# Processing Record 2 of Set 7 | darhan
# Processing Record 3 of Set 7 | pareora
# Processing Record 4 of Set 7 | taltal
# Processing Record 5 of Set 7 | tabuk
# Processing Record 6 of Set 7 | margate
# Processing Record 7 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | beya
# Processing Record 11 of Set 7 | abu dhabi
# Processing Record 12 of Set 7 | praia da vitoria
# Processing Record 13 of Set 7 | siyabuswa
# Processing Record 14 of Set 7 | annau
# Processing Record 15 of Set 7 | goderich
# Processing Record 16 of Set 7 | sept-iles
# Processing Record 17 of Set 7 | tadine
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | marzuq
# Processing Record 20 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 7 | khasan
# Processing Record 22 of Set 7 | coahuayana
# Processing Record 23 of Set 7 | kahului
# Processing Record 24 of Set 7 | luanda
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | fortuna
# Processing Record 27 of Set 7 | naze
# Processing Record 28 of Set 7 | ginda
# Processing Record 29 of Set 7 | larsnes
# Processing Record 30 of Set 7 | caravelas
# Processing Record 31 of Set 7 | matara
# Processing Record 32 of Set 7 | bambanglipuro
# Processing Record 33 of Set 7 | palo alto
# Processing Record 34 of Set 7 | aksu
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | nenjiang
# Processing Record 38 of Set 7 | roblin
# Processing Record 39 of Set 7 | zandvoort
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | mouila
# Processing Record 42 of Set 7 | srandakan
# Processing Record 43 of Set 7 | quatre cocos
# Processing Record 44 of Set 7 | ilo
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | guanambi
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | prabumulih
# Processing Record 49 of Set 7 | khvorostyanka
# Processing Record 50 of Set 7 | manicore
# Processing Record 1 of Set 8 | hurghada
# Processing Record 2 of Set 8 | meteti
# Processing Record 3 of Set 8 | usinsk
# Processing Record 4 of Set 8 | soyo
# Processing Record 5 of Set 8 | souillac
# Processing Record 6 of Set 8 | havre-saint-pierre
# Processing Record 7 of Set 8 | mejorada del campo
# Processing Record 8 of Set 8 | sugal
# Processing Record 9 of Set 8 | warragul
# Processing Record 10 of Set 8 | yurimaguas
# Processing Record 11 of Set 8 | alipur
# Processing Record 12 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 13 of Set 8 | nelson bay
# Processing Record 14 of Set 8 | saint anthony
# Processing Record 15 of Set 8 | ahipara
# Processing Record 16 of Set 8 | umuahia
# Processing Record 17 of Set 8 | banapur
# Processing Record 18 of Set 8 | shaunavon
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | darnah
# Processing Record 21 of Set 8 | naryan-mar
# Processing Record 22 of Set 8 | paamiut
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | ramhormoz
# Processing Record 25 of Set 8 | kloulklubed
# Processing Record 26 of Set 8 | huarmey
# Processing Record 27 of Set 8 | buala
# Processing Record 28 of Set 8 | balykshi
# Processing Record 29 of Set 8 | lucea
# Processing Record 30 of Set 8 | pelym
# Processing Record 31 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 8 | barvinkove
# Processing Record 33 of Set 8 | san ignacio
# Processing Record 34 of Set 8 | tommot
# Processing Record 35 of Set 8 | calbuco
# Processing Record 36 of Set 8 | saint-pierre
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | oranjemund
# Processing Record 39 of Set 8 | taybad
# Processing Record 40 of Set 8 | mbaiki
# Processing Record 41 of Set 8 | dehloran
# Processing Record 42 of Set 8 | parras
# City not found. Skipping...
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | cidreira
# Processing Record 45 of Set 8 | tet
# Processing Record 46 of Set 8 | maniitsoq
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | inhambane
# Processing Record 49 of Set 8 | ballesteros
# Processing Record 50 of Set 8 | manggar
# Processing Record 1 of Set 9 | urucara
# Processing Record 2 of Set 9 | contamana
# Processing Record 3 of Set 9 | mukhen
# Processing Record 4 of Set 9 | san rafael
# Processing Record 5 of Set 9 | yangambi
# Processing Record 6 of Set 9 | suntar
# Processing Record 7 of Set 9 | vung tau
# Processing Record 8 of Set 9 | batemans bay
# Processing Record 9 of Set 9 | weligama
# Processing Record 10 of Set 9 | nhulunbuy
# Processing Record 11 of Set 9 | whitehorse
# Processing Record 12 of Set 9 | monroe
# Processing Record 13 of Set 9 | hastings
# Processing Record 14 of Set 9 | kavaratti
# Processing Record 15 of Set 9 | puerto montt
# Processing Record 16 of Set 9 | mnogovershinnyy
# Processing Record 17 of Set 9 | high level
# Processing Record 18 of Set 9 | challapata
# Processing Record 19 of Set 9 | orotukan
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | leeuwarden
# Processing Record 22 of Set 9 | benguela
# Processing Record 23 of Set 9 | trincomalee
# Processing Record 24 of Set 9 | berlevag
# Processing Record 25 of Set 9 | altay
# Processing Record 26 of Set 9 | orchard homes
# Processing Record 27 of Set 9 | galle
# Processing Record 28 of Set 9 | talnakh
# Processing Record 29 of Set 9 | rio gallegos
# Processing Record 30 of Set 9 | sao felix do xingu
# Processing Record 31 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 9 | vryburg
# Processing Record 33 of Set 9 | brokopondo
# Processing Record 34 of Set 9 | mana
# Processing Record 35 of Set 9 | marsh harbour
# Processing Record 36 of Set 9 | cruden bay
# City not found. Skipping...
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | provideniya
# Processing Record 39 of Set 9 | pangnirtung
# Processing Record 40 of Set 9 | hirara
# Processing Record 41 of Set 9 | polunochnoye
# Processing Record 42 of Set 9 | nyangao
# Processing Record 43 of Set 9 | tinaquillo
# Processing Record 44 of Set 9 | kalmunai
# Processing Record 45 of Set 9 | takoradi
# Processing Record 46 of Set 9 | lakhdenpokhya
# Processing Record 47 of Set 9 | bogashevo
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | kangaatsiaq
# Processing Record 1 of Set 10 | fengzhen
# Processing Record 2 of Set 10 | atar
# Processing Record 3 of Set 10 | bani walid
# Processing Record 4 of Set 10 | saint-francois
# Processing Record 5 of Set 10 | kemijarvi
# Processing Record 6 of Set 10 | maridi
# Processing Record 7 of Set 10 | mocajuba
# Processing Record 8 of Set 10 | teguise
# Processing Record 9 of Set 10 | concordia
# Processing Record 10 of Set 10 | moose factory
# Processing Record 11 of Set 10 | san andres
# Processing Record 12 of Set 10 | acajutla
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | bridlington
# Processing Record 15 of Set 10 | port augusta
# Processing Record 16 of Set 10 | zlobin
# Processing Record 17 of Set 10 | byron bay
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | de aar
# Processing Record 20 of Set 10 | itoman
# Processing Record 21 of Set 10 | cuamba
# Processing Record 22 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | ornskoldsvik
# Processing Record 25 of Set 10 | hauterive
# Processing Record 26 of Set 10 | novouzensk
# Processing Record 27 of Set 10 | mumford
# Processing Record 28 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 30 of Set 10 | te anau
# Processing Record 31 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | zharkent
# Processing Record 33 of Set 10 | camacha
# Processing Record 34 of Set 10 | boa vista
# Processing Record 35 of Set 10 | qandala
# Processing Record 36 of Set 10 | wewak
# Processing Record 37 of Set 10 | ovalle
# Processing Record 38 of Set 10 | anadyr
# Processing Record 39 of Set 10 | miyazu
# Processing Record 40 of Set 10 | seoul
# Processing Record 41 of Set 10 | arona
# Processing Record 42 of Set 10 | mossendjo
# Processing Record 43 of Set 10 | arequipa
# Processing Record 44 of Set 10 | zwedru
# Processing Record 45 of Set 10 | yumbe
# Processing Record 46 of Set 10 | marrakesh
# Processing Record 47 of Set 10 | solnechnyy
# Processing Record 48 of Set 10 | paka
# Processing Record 49 of Set 10 | acahay
# Processing Record 50 of Set 10 | sidi ali
# Processing Record 1 of Set 11 | urucui
# Processing Record 2 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 11 | brindisi
# Processing Record 4 of Set 11 | perth
# Processing Record 5 of Set 11 | salinopolis
# Processing Record 6 of Set 11 | batouri
# Processing Record 7 of Set 11 | ye
# City not found. Skipping...
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | otradnoye
# Processing Record 10 of Set 11 | san quintin
# Processing Record 11 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 11 | areia branca
# Processing Record 13 of Set 11 | hohhot
# Processing Record 14 of Set 11 | bilibino
# Processing Record 15 of Set 11 | ostrovnoy
# Processing Record 16 of Set 11 | huntsville
# Processing Record 17 of Set 11 | eregli
# Processing Record 18 of Set 11 | salamiyah
# Processing Record 19 of Set 11 | nossa senhora da gloria
# Processing Record 20 of Set 11 | olinda
# Processing Record 21 of Set 11 | churapcha
# Processing Record 22 of Set 11 | egvekinot
# Processing Record 23 of Set 11 | ketchikan
# Processing Record 24 of Set 11 | brigantine
# Processing Record 25 of Set 11 | verkh-suetka
# Processing Record 26 of Set 11 | siguiri
# Processing Record 27 of Set 11 | erzin
# Processing Record 28 of Set 11 | bam
# Processing Record 29 of Set 11 | amapa
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | foam lake
# Processing Record 32 of Set 11 | coquimbo
# Processing Record 33 of Set 11 | opuwo
# Processing Record 34 of Set 11 | sabaudia
# Processing Record 35 of Set 11 | port hardy
# Processing Record 36 of Set 11 | strezhevoy
# Processing Record 37 of Set 11 | maham
# Processing Record 38 of Set 11 | coihaique
# Processing Record 39 of Set 11 | bonthe
# Processing Record 40 of Set 11 | celestun
# Processing Record 41 of Set 11 | san ramon
# Processing Record 42 of Set 11 | piedras negras
# Processing Record 43 of Set 11 | srednekolymsk
# Processing Record 44 of Set 11 | pokhara
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | marang
# Processing Record 47 of Set 11 | nishihara
# Processing Record 48 of Set 11 | les cayes
# Processing Record 49 of Set 11 | bosaso
# Processing Record 50 of Set 11 | hay river
# Processing Record 1 of Set 12 | indiaroba
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 12 | kaeo
# Processing Record 5 of Set 12 | dandong
# Processing Record 6 of Set 12 | yusva
# City not found. Skipping...
# Processing Record 7 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 12 | shakawe
# Processing Record 9 of Set 12 | chase
# Processing Record 10 of Set 12 | gat
# Processing Record 11 of Set 12 | maragogi
# Processing Record 12 of Set 12 | sabang
# Processing Record 13 of Set 12 | rundu
# Processing Record 14 of Set 12 | miramar
# Processing Record 15 of Set 12 | shediac
# Processing Record 16 of Set 12 | mombaca
# Processing Record 17 of Set 12 | heinola
# Processing Record 18 of Set 12 | aguimes
# Processing Record 19 of Set 12 | jaru
# Processing Record 20 of Set 12 | safaqis
# City not found. Skipping...
# Processing Record 21 of Set 12 | marienburg
# Processing Record 22 of Set 12 | iwaki
# Processing Record 23 of Set 12 | viedma
# Processing Record 24 of Set 12 | teya
# Processing Record 25 of Set 12 | bulgan
# Processing Record 26 of Set 12 | mwinilunga
# Processing Record 27 of Set 12 | ismailia
# Processing Record 28 of Set 12 | svetlogorsk
# Processing Record 29 of Set 12 | grand gaube
# Processing Record 30 of Set 12 | santa ana
# Processing Record 31 of Set 12 | kushmurun
# Processing Record 32 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 12 | inyonga
# Processing Record 34 of Set 12 | uchiza
# Processing Record 35 of Set 12 | kilindoni
# Processing Record 36 of Set 12 | cassilandia
# Processing Record 37 of Set 12 | zadonsk
# Processing Record 38 of Set 12 | cabinda
# Processing Record 39 of Set 12 | sinnamary
# Processing Record 40 of Set 12 | peachland
# Processing Record 41 of Set 12 | rudnaya pristan
# Processing Record 42 of Set 12 | chernyshevskiy
# Processing Record 43 of Set 12 | ramnicu sarat
# Processing Record 44 of Set 12 | bardiyah
# Processing Record 45 of Set 12 | carlsbad
# Processing Record 46 of Set 12 | itarema
# Processing Record 47 of Set 12 | upington
# Processing Record 48 of Set 12 | eatonton
# Processing Record 49 of Set 12 | ambatondrazaka
# Processing Record 50 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 1 of Set 13 | christchurch
# Processing Record 2 of Set 13 | todos santos
# Processing Record 3 of Set 13 | nantucket
# Processing Record 4 of Set 13 | hualmay
# Processing Record 5 of Set 13 | algarrobo
# Processing Record 6 of Set 13 | uthal
# Processing Record 7 of Set 13 | alyangula
# Processing Record 8 of Set 13 | opotiki
# Processing Record 9 of Set 13 | vao
# Processing Record 10 of Set 13 | smithers
# Processing Record 11 of Set 13 | patacamaya
# Processing Record 12 of Set 13 | haileybury
# Processing Record 13 of Set 13 | kishanganj
# Processing Record 14 of Set 13 | rio branco
# Processing Record 15 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 13 | kavieng
# Processing Record 17 of Set 13 | sheboygan
# Processing Record 18 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 19 of Set 13 | faya
# Processing Record 20 of Set 13 | ranot
# Processing Record 21 of Set 13 | saint-denis
# Processing Record 22 of Set 13 | carndonagh
# Processing Record 23 of Set 13 | batagay-alyta
# Processing Record 24 of Set 13 | lugo
# Processing Record 25 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 26 of Set 13 | masterton
# Processing Record 27 of Set 13 | rudnogorsk
# Processing Record 28 of Set 13 | twentynine palms
# Processing Record 29 of Set 13 | buritis
# Processing Record 30 of Set 13 | japura
# Processing Record 31 of Set 13 | sola
# Processing Record 32 of Set 13 | port lincoln
# Processing Record 33 of Set 13 | arman
# Processing Record 34 of Set 13 | meulaboh
# Processing Record 35 of Set 13 | opunake
# Processing Record 36 of Set 13 | shingu
# Processing Record 37 of Set 13 | antofagasta
# Processing Record 38 of Set 13 | hambantota
# Processing Record 39 of Set 13 | piacabucu
# Processing Record 40 of Set 13 | aurich
# Processing Record 41 of Set 13 | kutum
# Processing Record 42 of Set 13 | senanga
# Processing Record 43 of Set 13 | empalme
# Processing Record 44 of Set 13 | bogorodskoye
# Processing Record 45 of Set 13 | xai-xai
# Processing Record 46 of Set 13 | excelsior springs
# Processing Record 47 of Set 13 | katobu
# Processing Record 48 of Set 13 | mizan teferi
# Processing Record 49 of Set 13 | bilma
# Processing Record 50 of Set 13 | belmonte
# Processing Record 1 of Set 14 | gilbues
# Processing Record 2 of Set 14 | taksimo
# Processing Record 3 of Set 14 | rio grande
# Processing Record 4 of Set 14 | normandin
# Processing Record 5 of Set 14 | gizo
# Processing Record 6 of Set 14 | tocopilla
# Processing Record 7 of Set 14 | sibolga
# Processing Record 8 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 9 of Set 14 | diamantino
# Processing Record 10 of Set 14 | tarko-sale
# Processing Record 11 of Set 14 | maldonado
# Processing Record 12 of Set 14 | henties bay
# Processing Record 13 of Set 14 | qui nhon
# Processing Record 14 of Set 14 | nata
# Processing Record 15 of Set 14 | amazar
# Processing Record 16 of Set 14 | ocampo
# Processing Record 17 of Set 14 | champerico
# Processing Record 18 of Set 14 | california city
# Processing Record 19 of Set 14 | katherine
# Processing Record 20 of Set 14 | axim
# Processing Record 21 of Set 14 | borogontsy
# Processing Record 22 of Set 14 | kuusamo
# Processing Record 23 of Set 14 | zhangye
# Processing Record 24 of Set 14 | zhicheng
# Processing Record 25 of Set 14 | jalu
# Processing Record 26 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 14 | joensuu
# Processing Record 28 of Set 14 | pundaguitan
# Processing Record 29 of Set 14 | vinh
# Processing Record 30 of Set 14 | roebourne
# Processing Record 31 of Set 14 | banda aceh
# Processing Record 32 of Set 14 | kudahuvadhoo
# Processing Record 33 of Set 14 | asfi
# Processing Record 34 of Set 14 | baherden
# Processing Record 35 of Set 14 | asau
# Processing Record 36 of Set 14 | kapuskasing
# Processing Record 37 of Set 14 | khovu-aksy
# Processing Record 38 of Set 14 | baoning
# Processing Record 39 of Set 14 | wainwright
# Processing Record 40 of Set 14 | lagoa vermelha
# Processing Record 41 of Set 14 | brae
# Processing Record 42 of Set 14 | minot
# Processing Record 43 of Set 14 | chodavaram
# Processing Record 44 of Set 14 | vila
# Processing Record 45 of Set 14 | santa maria
# Processing Record 46 of Set 14 | mahibadhoo
# Processing Record 47 of Set 14 | businga
# Processing Record 48 of Set 14 | ust-nera
# Processing Record 49 of Set 14 | shenkursk
# Processing Record 50 of Set 14 | lasa
# Processing Record 1 of Set 15 | lima
# Processing Record 2 of Set 15 | ancud
# Processing Record 3 of Set 15 | banjar
# Processing Record 4 of Set 15 | morondava
# Processing Record 5 of Set 15 | kirkuk
# Processing Record 6 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 7 of Set 15 | kamaishi
# Processing Record 8 of Set 15 | sapele
# Processing Record 9 of Set 15 | trondheim
# Processing Record 10 of Set 15 | vestmanna
# Processing Record 11 of Set 15 | presidencia roque saenz pena
# Processing Record 12 of Set 15 | berdigestyakh
# Processing Record 13 of Set 15 | waitati
# Processing Record 14 of Set 15 | khash
# Processing Record 15 of Set 15 | cabra
# Processing Record 16 of Set 15 | vila franca do campo
# Processing Record 17 of Set 15 | san buenaventura
# Processing Record 18 of Set 15 | kimberley
# Processing Record 19 of Set 15 | voznesenka
# Processing Record 20 of Set 15 | jand
# Processing Record 21 of Set 15 | mayumba
# Processing Record 22 of Set 15 | safford
# Processing Record 23 of Set 15 | severo-yeniseyskiy
# Processing Record 24 of Set 15 | honiara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pevek      RU  69.7008  170.3133    -11.76       100          56
# 1      Havelock      US  34.8791  -76.9013     57.06        41           1
# 2       Ushuaia      AR -54.8000  -68.3000     56.86        47          20
# 3    Lavrentiya      RU  65.5833 -171.0000    -12.69        88           7
# 4      Bengkulu      ID  -3.8004  102.2655     75.60        87         100
# 5        Barrow      US  71.2906 -156.7887    -16.58        69           1
# 6         Nyrob      RU  60.7330   56.7202     33.51        97         100
# 7     Mahebourg      MU -20.4081   57.7000     77.29        73          20
# 8      Nacozari      MX  25.3366 -108.2574     77.11        42          98
# 9  Puerto Ayora      EC  -0.7393  -90.3518     76.96        89          92
#
#    Wind Speed Current Description
# 0        1.72       broken clouds
# 1        5.01           clear sky
# 2       10.36          few clouds
# 3        8.63           clear sky
# 4        7.43     overcast clouds
# 5        8.05                haze
# 6       14.20                snow
# 7        2.30          few clouds
# 8        4.76     overcast clouds
# 9        7.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
